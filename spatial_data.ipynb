# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasudevan0057/DHV/blob/main/spatial_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
mymap = folium.Map(location = [1.366623,103.821285],
                 width=950,
                 height=550,
                 zoom_start=12,
                 tiles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed7e6e20f973b014cad8cf6d855fd5bd {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed7e6e20f973b014cad8cf6d855fd5bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed7e6e20f973b014cad8cf6d855fd5bd = L.map(
#                 &quot;map_ed7e6e20f973b014cad8cf6d855fd5bd&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd0e3b12684e12c33ca68d13429bb853 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed7e6e20f973b014cad8cf6d855fd5bd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
mymap = folium.Map(location=[0, 0], zoom_start=2)
folium.Marker(location=[14.3134,  76.6510], popup='Challakere', icon=folium.Icon(color='blue')).add_to(mymap)
folium.Marker(location=[13.2678,76.4490], popup='Tiptur', icon=folium.Icon(color='green')).add_to(mymap)
folium.Marker(location=[131533.5,762842.0], popup='Tokyo', icon=folium.Icon(color='red')).add_to(mymap)
folium.Marker([12.9958, 77.6039], popup='Pointer 1', icon=folium.Icon(color='red')).add_to(mymap)
folium.Marker([ 12.9741, 77.6081], popup='MG road', icon=folium.Icon(color='black')).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bcff6ce9c36b3d7500fe51130314225 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bcff6ce9c36b3d7500fe51130314225&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bcff6ce9c36b3d7500fe51130314225 = L.map(
#                 &quot;map_3bcff6ce9c36b3d7500fe51130314225&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48636fb3e093275e95955a8cd8ca4d93 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3bcff6ce9c36b3d7500fe51130314225);
#
#
#             var marker_ba68ec5d64e6c57f72f62631f877b0c4 = L.marker(
#                 [14.3134, 76.651],
#                 {}
#             ).addTo(map_3bcff6ce9c36b3d7500fe51130314225);
#
#
#             var icon_e60f9fd9d9ec161bfeb2bc5ef491202a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba68ec5d64e6c57f72f62631f877b0c4.setIcon(icon_e60f9fd9d9ec161bfeb2bc5ef491202a);
#
#
#         var popup_b009deb815d6ed9127a3af57901abef4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05270e5b6b0d412bbe4fdbfb0cd306d5 = $(`&lt;div id=&quot;html_05270e5b6b0d412bbe4fdbfb0cd306d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Challakere&lt;/div&gt;`)[0];
#                 popup_b009deb815d6ed9127a3af57901abef4.setContent(html_05270e5b6b0d412bbe4fdbfb0cd306d5);
#
#
#
#         marker_ba68ec5d64e6c57f72f62631f877b0c4.bindPopup(popup_b009deb815d6ed9127a3af57901abef4)
#         ;
#
#
#
#
#             var marker_b8ec02523daa3e27962c4155a525b573 = L.marker(
#                 [13.2678, 76.449],
#                 {}
#             ).addTo(map_3bcff6ce9c36b3d7500fe51130314225);
#
#
#             var icon_1a86b2bf29af754f09c63be8260e91d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8ec02523daa3e27962c4155a525b573.setIcon(icon_1a86b2bf29af754f09c63be8260e91d8);
#
#
#         var popup_920a4cff10051cac48fa35093d47d650 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf172ea95b8d62d28dbd2bc55de3e0d8 = $(`&lt;div id=&quot;html_bf172ea95b8d62d28dbd2bc55de3e0d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tiptur&lt;/div&gt;`)[0];
#                 popup_920a4cff10051cac48fa35093d47d650.setContent(html_bf172ea95b8d62d28dbd2bc55de3e0d8);
#
#
#
#         marker_b8ec02523daa3e27962c4155a525b573.bindPopup(popup_920a4cff10051cac48fa35093d47d650)
#         ;
#
#
#
#
#             var marker_cc58fc73ca7b64dae77d03161b8f2218 = L.marker(
#                 [131533.5, 762842.0],
#                 {}
#             ).addTo(map_3bcff6ce9c36b3d7500fe51130314225);
#
#
#             var icon_43fad082e0c153a94e4f326497d91fe3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc58fc73ca7b64dae77d03161b8f2218.setIcon(icon_43fad082e0c153a94e4f326497d91fe3);
#
#
#         var popup_016149e8f894eb20e2d0203970ff2e39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7566719c54045952f1b4d41cfb865a6 = $(`&lt;div id=&quot;html_d7566719c54045952f1b4d41cfb865a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo&lt;/div&gt;`)[0];
#                 popup_016149e8f894eb20e2d0203970ff2e39.setContent(html_d7566719c54045952f1b4d41cfb865a6);
#
#
#
#         marker_cc58fc73ca7b64dae77d03161b8f2218.bindPopup(popup_016149e8f894eb20e2d0203970ff2e39)
#         ;
#
#
#
#
#             var marker_d202bce2c57bac28bc54a8ae4aa12fd7 = L.marker(
#                 [12.9958, 77.6039],
#                 {}
#             ).addTo(map_3bcff6ce9c36b3d7500fe51130314225);
#
#
#             var icon_eb920388ce815c22975a8b1240ffbdd5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;whi
